# %% [markdown]
# <a href="https://colab.research.google.com/github/Koveraaman/DL_CHENNAI_LANDSALE_PREDICTION/blob/main/DL_CHENNAI_LANDSALE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("/content/train-chennai-sale.csv")
df
# Out:
#       PRT_ID        AREA  INT_SQFT   DATE_SALE  DIST_MAINROAD  N_BEDROOM  \
# 0     P03210  Karapakkam      1004    4/5/2011            131        1.0
# 1     P09411  Anna Nagar      1986  19/12/2006             26        2.0
# 2     P01812       Adyar       909    4/2/2012             70        1.0
# 3     P05346   Velachery      1855   13/3/2010             14        3.0
# 4     P06210  Karapakkam      1226   5/10/2009             84        1.0
# ...      ...         ...       ...         ...            ...        ...
# 7104  P03834  Karapakkam       598    3/1/2011             51        1.0
# 7105  P10000   Velachery      1897    8/4/2004             52        3.0
# 7106  P09594   Velachery      1614   25/8/2006            152        2.0
# 7107  P06508  Karapakkam       787    3/8/2009             40        1.0
# 7108  P09794   Velachery      1896   13/7/2005            156        3.0
#
#       N_BATHROOM  N_ROOM    SALE_COND PARK_FACIL  ... UTILITY_AVAIL  \
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
df.isnull().sum()
# Out:
# PRT_ID            0
# AREA              0
# INT_SQFT          0
# DATE_SALE         0
# DIST_MAINROAD     0
# N_BEDROOM         1
# N_BATHROOM        5
# N_ROOM            0
# SALE_COND         0
# PARK_FACIL        0
# DATE_BUILD        0
# BUILDTYPE         0
# UTILITY_AVAIL     0
# STREET            0
# MZZONE            0
# QS_ROOMS          0
# QS_BATHROOM       0
# QS_BEDROOM        0
# QS_OVERALL       48
# REG_FEE           0
# COMMIS            0
# SALES_PRICE       0
# dtype: int64

# %%
df['AREA'].unique()
# Out:
# array(['Karapakkam', 'Anna Nagar', 'Adyar', 'Velachery', 'Chrompet',
#        'KK Nagar', 'T Nagar', 'Karapakam'], dtype=object)

# %%
df['AREA'] = df['AREA'].apply(lambda x: 'Anna Nagar' if x == 'Ana Nagar' or x == 'Ann Nagar' else x)
df['AREA'] = df['AREA'].apply(lambda x: 'Chrompet' if x == 'Chormpet' or x == 'Chrompt' or x == 'Chrmpet' else x)
df['AREA'] = df['AREA'].apply(lambda x: 'T Nagar' if x == 'TNagar' else x)
df['AREA'] = df['AREA'].apply(lambda x: 'Velachery' if x == 'Velchery' else x)
df['AREA'] = df['AREA'].apply(lambda x: 'KarapaKkam' if x == 'Karapakam A' else x)
df['AREA'] = df['AREA'].apply(lambda x: 'Adyar' if x == 'Adyr' else x)
df['AREA'] = df['AREA'].apply(lambda x: 'KK Nagar' if x == 'KKNagar' else x)

# %%
df['SALE_COND'].unique()
# Out:
# array(['Abnormal', 'Family', 'Partial', 'Adjland', 'Normal Sale'],
#       dtype=object)

# %%
df['SALE_COND']= df['SALE_COND'].apply(lambda x: 'Abnormal' if x == 'AbNormal' or x == 'Ab Normal' else x)
df['SALE_COND']= df['SALE_COND'].apply(lambda x: 'Adjland' if x == 'AdjLand' or x == 'Adj Land' else x)
df['SALE_COND']= df['SALE_COND'].apply(lambda x: 'Partial' if x == 'Partiall' or x == 'PartiaLl' else x)
